# %% [markdown]
# My First Gemini Chatbot

# %%
import streamlit as st
from pathlib import Path
import google.genai as genai

# %%
client = genai.Client(api_key="AIzaSyBqQdlIbxJrr4ZvHsgO5T9egMCP6VQmMgc")

# %%
system_prompt = """You are a helpful assistant for answering questions about the Python code in the notebook."""

# %%
from google.genai import types

# %%
generation_config = types.GenerationConfig( 
    temperature=1,
    top_p=0.95,
    top_k=40,
    max_output_tokens=8192,
    response_mime_type="text/plain",
    stop_sequences=["### End of answer"],
)

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Your question about the code in the notebook goes here.",
    config={
        "system_instruction": system_prompt,
        "temperature": 1,
        "top_p": 0.95,
        "top_k": 40,
        "max_output_tokens": 8192,
        "response_mime_type": "text/plain",
        "stop_sequences": ["### End of answer"]
    }
)

# %%
print(response.text)
# Out:
# In the context of Python programming, when we talk about a "notebook," we are almost certainly referring to a **Jupyter Notebook** (or a similar interactive environment like Google Colab, VS Code Notebooks, etc.).
#
# Here's what it is and what it does:
#
# 1.  **Interactive Document:** A Jupyter Notebook is a web-based interactive computing environment that allows you to create and share documents containing:
#     *   **Live Code:** Executable Python code (or other languages).
#     *   **Narrative Text:** Markdown text (for explanations, comments, headings).
#     *   **Equations:** Using LaTeX.
#     *   **Visualizations:** Charts, plots, and images.
#     *   **Rich Media:** Videos, animations, etc.
#
# 2.  **Cells:** Notebooks are structured into "cells." There are two primary types:
#     *   **Code Cells:** Where you write and execute Python code. The output of the code (like print statements, variable values, plots) appears directly below the cell.
#     *   **Markdown Cells:** Where you write formatted text using Markdown syntax to explain your code, describe your analysis, or provide context.
#
# 3.  **Purpose:**
#     *   **Iterative Development:** It's excellent for experimenting with code snippets, seeing immediate results, and building up a program step-by-step.
#     *   **Data Science & Machine Learning:** Widely used for data exploration, cleaning, analysis, model building, and visualization because you can easily combine code, data outputs, and explanatory text.
#     *   **Documentation & Communication:** You can run your code and then save the notebook with all its outputs and explanations, making it a self-contained report that others can easily understand and reproduce.
#     *   **Education:** Ideal for teaching and learning programming as students can execute code examples and see their effects instantly.
#
# In short, a "notebook" provides an interactive canvas where you can write and run Python code, explain your thought process, and display the results, all in one document.

# %%
import streamlit as st
from google import genai
from google.genai import types

# %%
client = genai.Client(api_key="AIzaSyBqQdlIbxJrr4ZvHsgO5T9egMCP6VQmMgc")

# %%
st.set_page_config(page_title="My Gemini Chatbot", page_icon=":robot:")
st.title("My Gemini Chatbot")
# Out:
# 2026-02-12 12:02:15.099 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:02:15.134 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:02:15.753
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-12 12:02:15.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:02:15.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
if "messages" not in st.session_state:
    st.session_state.messages = []
# Out:
# 2026-02-12 12:02:50.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:02:50.822 Session state does not function when running a script without `streamlit run`
# 2026-02-12 12:02:50.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:02:50.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
for message in st.session_state.messages:
    with st.chat_message(message["role"]):
        st.markdown(message["content"])
# Out:
# 2026-02-12 12:03:48.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if prompt := st.chat_input("Ask me anything about the code in this notebook!"):
    st.session_state.messages.append({"role": "user", "content": prompt})
    with st.chat_message("user"):
        st.markdown(prompt)
    
    
    with st.chat_message("assistant"):
        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=prompt,
            config={
                "system_instruction": system_prompt,
                "temperature": 1,
                "top_p": 0.95,
                "top_k": 40,
                "max_output_tokens": 8192,
            }
        )
        st.markdown(response.text)
        st.session_state.messages.append({"role": "assistant", "content": response.text})
# Out:
# 2026-02-12 12:08:04.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:08:04.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:08:04.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:08:04.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:08:04.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 12:08:04.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
